# %% [markdown]
# ## Add Sentiment Analysis as Column
#
# This jupyter book involves of calling the review dataset and read reviews to add a new column with sentiment analysis result of the review.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import iqr
import matplotlib.pyplot as plt
from datetime import datetime, date
import transformers
from transformers import pipeline
import torch

path=r"C:\Users\Metin\Desktop\Data Science - Jupyter\britishairlines_internship\data\BA_reviews_depth.csv"

df=pd.read_csv(path)



df['Review'] = df['Review'].map(lambda x: x.lstrip('✅ Trip Verified | '))
df['Review'] = df['Review'].map(lambda x: x.lstrip('Not Verified | '))

df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           0  Organised boarding process. Really friendly cr...
# 1           1  Outward journey BA245 London to Buenos Aires C...
# 2           2  Check in agent at LHR was very helpful and fri...
# 3           3  y disappointing. I book BA so I can fly during...
# 4           4  Excellent service both on the ground and on bo...
#
#          Aircraft     Travel Type        Seat Type    Date Flown  \
# 0            A320        Business    Economy Class  January 2023
# 1            A320  Couple Leisure  Premium Economy  January 2023
# 2  Boeing 777-300    Solo Leisure  Premium Economy  January 2023
# 3  Boeing 777-300    Solo Leisure    Economy Class  January 2023
# 4            A380    Solo Leisure      First Class  January 2023
#
#    Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0             5                    5                 4               5
# ...

# %%
sentiment_pipeline = pipeline("sentiment-analysis",model="distilbert-base-uncased-finetuned-sst-2-english")

df["sentinment"]=df["Review"].apply(lambda x: sentiment_pipeline(x[:512]))

# %%
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           0  Organised boarding process. Really friendly cr...
# 1           1  Outward journey BA245 London to Buenos Aires C...
# 2           2  Check in agent at LHR was very helpful and fri...
# 3           3  y disappointing. I book BA so I can fly during...
# 4           4  Excellent service both on the ground and on bo...
#
#          Aircraft     Travel Type        Seat Type    Date Flown  \
# 0            A320        Business    Economy Class  January 2023
# 1            A320  Couple Leisure  Premium Economy  January 2023
# 2  Boeing 777-300    Solo Leisure  Premium Economy  January 2023
# 3  Boeing 777-300    Solo Leisure    Economy Class  January 2023
# 4            A380    Solo Leisure      First Class  January 2023
#
#    Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0             5                    5                 4               5
# ...

# %%
df.to_csv(r"C:\Users\Metin\Desktop\Data Science - Jupyter\britishairlines_internship\data\BA_reviews_sentiment1.csv")
